# %%
import os
import sqlite3
import pandas
import functools
import peak

def cx_start():
    return sqlite3.connect(db_path)

db_path = f"..{os.sep}peak{os.sep}peak.db" 
cx = cx_start()

    
def cx_end():
    if cx:
        cx.close()
cx_start()
read = functools.partial(pandas.read_sql, con=cx)
dir(peak)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
read('select * from users')
# Out:
#      username                                              bhash
# 0  admin@peak  $2b$12$8GpEi5/VE/iBmiCaYLREquh2euZbyYvHmq/22PV...

# %%
read('select * from visits')
# Out:
#        member_id                 date
# 0         101743  2018-02-07 08:29:40
# 1         101743  2018-08-27 05:36:58
# 2         101743  2017-11-23 04:05:03
# 3         101743  2018-03-08 17:40:50
# 4         101743  2018-02-03 15:13:44
# 5         101743  2017-12-21 00:47:51
# 6         101743  2018-04-30 21:40:08
# 7         101743  2017-10-06 02:50:29
# 8         101743  2017-10-03 11:40:52
# 9         101743  2018-08-27 16:07:46
# 10        101743  2018-09-24 07:15:13
# 11        101743  2018-02-04 04:54:20
# 12        101743  2018-01-15 14:40:16
# 13        101743  2018-02-24 23:48:15
# 14        101743  2018-01-21 07:54:54
# 15        101743  2018-09-07 09:33:15
# 16        101743  2018-02-05 12:10:04
# 17        101743  2017-09-16 11:35:56
# 18        101743  2018-06-23 21:33:46
# 19        101743  2018-09-06 05:46:14
# 20        101743  2018-08-24 04:49:37
# 21        101743  2018-09-10 22:23:58
# 22        101743  2018-05-18 18:24:03
# 23        101743  2018-01-12 19:48:16
# ...

# %%
read("SELECT name FROM sqlite_master WHERE type='table'")
# Out:
#       name
# 0  clients
# 1   visits
# 2    users

# %%
read('select * from clients')
# Out:
#                        name      username                number  \
# 0               Connor Rice         crice            6126665555
# 1             Craig Mueller      cmueller          102-856-9598
# 2     Mr. Christopher Kelly  mchristopher     (532)727-8903x537
# 3             Logan Dickson      ldickson           09763153253
# 4                Dawn Poole        dpoole      074.111.6747x532
# 5       Stephanie Carpenter    scarpenter        1-539-850-0365
# 6            Bethany Hardin       bhardin    1-485-372-4255x073
# 7              Adam Sanders      asanders     131.306.2910x3828
# 8           Alexandra Davis        adavis          016-711-8020
# 9             Natalie Green        ngreen     224.886.7852x7076
# 10           Justin Hoffman      jhoffman           03047351214
# 11           Miranda Pierce       mpierce  1-250-219-3486x00663
# 12           Regina Edwards      redwards         (955)247-2704
# 13           Crystal Taylor       ctaylor         (731)835-0057
# ...
