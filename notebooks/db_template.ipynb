# %%
import os
import sqlite3
import pandas
import functools
import pip
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    

peak_path = os.path.join(module_path, 'peak')
astral_path = os.path.join(module_path, 'astral')

sys.path.append(peak_path)
sys.path.append(astral_path)

def cx_start():
    return sqlite3.connect(db_path)
    

db_path = f"..{os.sep}peak{os.sep}peak.db" 
cx = cx_start()


def cx_end(cx):
    if cx:
        cx.close()
cx_start()
read = functools.partial(pandas.read_sql, con=cx)
print()
import sys
sys.path
# Out:
# ['',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\python36.zip',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\DLLs',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\oss-0.0.1-py3.6.egg',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\tornado-4.5.2-py3.6-win-amd64.egg',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\dataviz-0.1.1337-py3.6.egg',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\pyinstaller-3.3-py3.6.egg',
#  'c:\\users\\conno\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\pypyodbc-1.3.4-py3.6.egg',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-fdd93df440d0> in <module>()
# ----> 1 import astralv
#
# ModuleNotFoundError: No module named 'astralv'

# %%
read('select * from clients')
# Out:
#                       name     username                number  \
# 0              Connor Rice        crice            6126665555
# 1              Hannah Ward        hward          688-213-3008
# 2         Michelle Jackson     mjackson    1-315-857-6473x140
# 3     Mrs. Margaret Wright    mmargaret    424-471-8171x51453
# 4           Vanessa Bailey      vbailey      787.527.9891x456
# 5             Lisa Santana     lsantana        1-062-566-2873
# 6         Stephanie Taylor      staylor  1-971-327-7347x27131
# 7            David Russell     drussell        1-028-105-1827
# 8              David Nixon       dnixon    186-602-5412x03677
# 9        Thomas Richardson  trichardson          168.138.4187
# 10       Robert Strickland  rstrickland          198-925-7822
# 11          Kimberly Jones       kjones      +77(2)2333969019
# 12          Michael Garcia      mgarcia   1-987-635-2251x4179
# 13            Mark Collins     mcollins      +10(7)0846914125
# ...

# %%
def list_tables(curs):
    curs.execute("SELECT name FROM sqlite_master WHERE type='table';")
    return sorted([i[0] for i in curs.fetchall()])

# %%
print(list_tables(cx.cursor()))
# Out:
# ['clients', 'users', 'visits']

# %%
read('select * from clients').to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>name</th>\n      <th>username</th>\n      <th>number</th>\n      <th>address</th>\n      <th>email</th>\n      <th>total_income</th>\n      <th>memberid</th>\n      <th>start_date</th>\n      <th>end_date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Connor Rice</td>\n      <td>crice</td>\n      <td>6126665555</td>\n      <td>Kappa St</td>\n      <td>admin@peak.ninja</td>\n      <td>350</td>\n      <td>101743</td>\n      <td>2017-09-01 00:00:00</td>\n      <td>2050-09-01 00:00:00</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Hannah Ward</td>\n      <td>hward</td>\n      <td>688-213-3008</td>\n      <td>8319 Billy Street\\nLaurabury, MP 69567</td>\n      <td>robertsalison@gmail.com</td>\n      <td>96368</td>\n      <td>6924862</td>\n      <td>2015-09-23 00:00:00</td>\n      <td>2016-09-22 00:00:00</td>\n    </tr>\n    <tr>\n      <t
# ...
